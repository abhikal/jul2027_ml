# %%
def fit(x1, y1, x2, y2):
    return 4, -1

# %% [markdown]
# https://docs.google.com/spreadsheets/d/1jJd1XxDe-QRL3my_V06nJdQOe2c9_KuDOoopVmxoiQY/edit?usp=sharing

# %%
from numpy import diff


def error(x1, x2, x3, y1, y2, y3, m, c):
    yp1 = 
    yp2 = 
    yp3 = 
    diff1, diff2, diff3 = ...
    error = diff1*diff2 ...
    return error
