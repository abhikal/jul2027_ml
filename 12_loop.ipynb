# %%
# 321 
# last 
321 % 10
# Out:
# 1

# %%
45 % 10
# Out:
# 5

# %%
1234 -> 123

# %%
1234 // 10
# Out:
# 123

# %%
5 // 2
# Out:
# 2

# %%
num = 12345688

# %%
num = num // 10
print(num)
# Out:
# 0

# %%
def remove_last_digit(num):
    return num // 10

# %%
def print_digit_one_in_line(num): #reverse order
    while num > 0:
        print(f"num: {num}")
        last_digit = num % 10
        print(f"Last Digit: {last_digit}")
        num = num // 10
    print(num)

# %%
# Emmanuel Urube (Sep 12, 2026, 11:19 AM)
def num ():
    num = 1234
    while num % 10 !=0:
        return num // 10
        print (num % 10)
        num = num // 10
    print (num)

# %%
print_digit_one_in_line(1234)
# Out:
# num: 1234
# Last Digit: 4
# num: 123
# Last Digit: 3
# num: 12
# Last Digit: 2
# num: 1
# Last Digit: 1
# 0

# %%
last_digit = 10
print(f"Last Digit: {last_digit}")
# Out:
# Last Digit: 10

# %%
# base8 -> base 10
123 -> 3 + 2 * 8 + 1*8*8

# %%
if single digit -> as is
if multiple of 10 -> 8 * digit

# %%
# ATISH AIIMS NEW DELHI (Sep 12, 2026, 11:58 AM)
def octal_to_decimal(octal_str):
    decimal_value = 0
    power = 0
    for digit in reversed(octal_str):
        decimal_value += int(digit) * (8 ** power)
        power += 1
    return decimal_value

# Test
octal_number = "157"
print(f"Octal {octal_number} in Decimal is {octal_to_decimal(octal_number)}")
# Out:
# Octal 157 in Decimal is 111

# %%
# Rajesh Singh (Sep 12, 2026, 12:08 PM)
# Here is my final code with Print:
# convert Base 8 to Base 10
def Base8_Base10(num):
    base10_num = 0
    i= 0
    print(f"num : {num}")
    while num > 0:
        last_num = num % 10
        base10_num += last_num*(8**i)
        print (f"Last_number is : {last_num}")
        num = num // 10
        i = i+1
    print(f"base10 of num is: {base10_num}")

# %%
def convert_base8_10(num):

# %%
def calculate_interest(p, r, t):
    print("p:", p)
    
    return p * r * t/100

# %%
calculate_interest(1000, 5, 2)
# Out:
# p: 1000
# 100.0

# %%
def myabs(x):
    if x < 0:
        return -x
    else:
        return +x
    
def manhattan_distance(x1, y1, x2, y2):
    return abs(x2- x1) + abs(y2 - y1)

def manhattan_distance(x1, y1, x2, y2):
    ydiff = myabs(y2 - y1)
    xdiff = myabs(x2 - x1)
    return ydiff + xdiff

# %%
def f(x):
    return 3 * x
# Out:
# 3

# %%
h = .00000001
y1 = f(1)
y2 = f(1 + h)

dy_dx = (y2 - y1)/h
dy_dx
# Out:
# 2.999999981767587

# %%
def diff(f, x):
    h = .00000000001
    y1 = f(x)
    y2 = f(x + h)
    return (y2 - y1)/h

# %%
# Improvement: 
# 1. we should keep h value to be small.
# 2. alternative - (f(x+h) - f(x - h))/2*h
def diff(f, x):
    h = 1e-10
    y1 = f(x)
    y2 = f(x + h)
    return (y2 - y1)/h

# %%
def myf(x):
    return 3*x 

diff(myf, 1)
# Out:
# 3.000000248221113

# %%
def sq(x):
    return x*x

diff(sq, 1) #2x
# Out:
# 2.000000165480742

# %%
diff(sq, 3)
# Out:
# 6.000000496442226

# %%
def cube(x):
    return x*x*x

diff(cube, 2) # 3*x*x
# Out:
# 12.000000992884452

# %%
def cube(x):
    return x*x*x

diff(cube, 10) # 3*x*x
# Out:
# 300.000237984932

# %% [markdown]
# # TODO: Test all the three definitions of differentiation
#
# A. (f(x + h) - f(x))/h
#
# B. (f(x) - f(x-h)) / h
#
# C. (f(x+h) - f(x-h))/(2*h)

# %%
def diff(f, x):
    h = 1e-10 # .0000000001
    y1 = ...
    y2 = ...
    return ...

# %% [markdown]
# - Check if your function is able to find derivative of log, exp, sin etc.
# - math.log, math.exp

# %%
# y = x**3, dy_dx = 3 * x**2
# y = x**2, dy_dx = 2x

# %%
def myf(x1, x2):
    return 5*x1*x1 + 3*x2

# %%
# find dy_dx1, dy_dx2 at x1 = 1, x2 = 2
diff2(myf, x1=1, x2=2)

# %%
def diff2(myf, x1, x2):
    h = 1e-10
    y = myf(x1, x2)
    dy_dx1 = (myf(x1 + h, x2) -  y)/h
    dy_dx2 = (myf(x1, x2 + h) -  y)/h
    return dy_dx1, dy_dx2

# %%
diff2(myf, x1=1, x2=2)
# Out:
# (10.00000082740371, 3.000000248221113)

# %%
# TODO: try to find a derivate of function having three arguments
