# %% [markdown]
# # log is number of zeros
#
# log(10) -> 1
# log(100) -> 2
# log(1000) -> 3
# log(1) -> 0
#
# log(10 ** 4) -> 4
# log(10 ** x) -> x
#
# import math
#
# math.log10(100)

# %%
import math 
math.log10(30)
# Out:
# 1.4771212547196624

# %%
10 ** 1.4771212547196624
# Out:
# 29.999999999999996

# %%
10 ** log(30) = 30

# %%
log (10 * 100) =  1 + 2

log (10 **x * 10 ** y) = x + y = log(10**x) + log(10 ** y)
log(A * B) = log(A) + log(B)

# %%
log(10) -> 1
log(100) -> 2
log(50) -> 1.5

# %%
10 ** 1.5
# Out:
# 31.622776601683793

# %%
10 ** 1.7
# Out:
# 50.11872336272722

# %%
10 ** 1.6
# Out:
# 39.810717055349734

# %%
10 ** 1.65
# Out:
# 44.6683592150963

# %%
lo = 1
hi = 2
guess = (lo + hi)/2
10 ** guess
# Out:
# 31.622776601683793

# %%
lo = guess 
guess = (lo + hi)/2
10 ** guess
# Out:
# 56.23413251903491

# %%
hi = guess 
guess = (lo + hi)/2
print(f"Guess: {guess}", 10 ** guess )
# Out:
# Guess: 1.625 42.169650342858226

# %%
lo = guess 
print(f"Lo: {lo}, Hi: {hi}")
guess = (lo + hi)/2
print(f"Guess: {guess}", 10 ** guess )
# Out:
# Lo: 1.625, Hi: 1.75
# Guess: 1.6875 48.69675251658631

# %%
if 10**guess < 50:
    lo = guess 
else:
    hi = guess 
print(f"Lo: {lo}, Hi: {hi}")
guess = (lo + hi)/2
print(f"Guess: {guess}", 10 ** guess )
# Out:
# Lo: 1.6875, Hi: 1.75
# Guess: 1.71875 52.32991146814947

# %%
if 10**guess < 50:
    lo = guess 
else:
    hi = guess 
print(f"Lo: {lo}, Hi: {hi}")
guess = (lo + hi)/2
print(f"Guess: {guess}", 10 ** guess )
# Out:
# Lo: 1.6875, Hi: 1.71875
# Guess: 1.703125 50.48065716667471

# %%
if 10**guess < 50:
    lo = guess 
else:
    hi = guess 
print(f"Lo: {lo}, Hi: {hi}")
guess = (lo + hi)/2
print(f"Guess: {guess}", 10 ** guess )
# Out:
# Lo: 1.6875, Hi: 1.703125
# Guess: 1.6953125 49.58068241684656

# %%
for i in range(20):
    if 10**guess < 50:
        lo = guess 
    else:
        hi = guess 
    print(f"Lo: {lo}, Hi: {hi}")
    guess = (lo + hi)/2
    print(f"Guess: {guess}", 10 ** guess )
# Out:
# Lo: 1.6953125, Hi: 1.703125
# Guess: 1.69921875 50.02864610575233
# Lo: 1.6953125, Hi: 1.69921875
# Guess: 1.697265625 49.80416061248411
# Lo: 1.697265625, Hi: 1.69921875
# Guess: 1.6982421875 49.916277163626866
# Lo: 1.6982421875, Hi: 1.69921875
# Guess: 1.69873046875 49.97243005033611
# Lo: 1.69873046875, Hi: 1.69921875
# Guess: 1.698974609375 50.0005301775164
# Lo: 1.69873046875, Hi: 1.698974609375
# Guess: 1.6988525390625 49.98647813934942
# Lo: 1.6988525390625, Hi: 1.698974609375
# Guess: 1.69891357421875 49.99350366471933
# Lo: 1.69891357421875, Hi: 1.698974609375
# Guess: 1.698944091796875 49.99701679768079
# Lo: 1.698944091796875, Hi: 1.698974609375
# Guess: 1.6989593505859375 49.99877345673824
# Lo: 1.6989593505859375, Hi: 1.698974609375
# Guess: 1.6989669799804688 49.9996518094121
# Lo: 1.6989669799804688, Hi: 1.698974609375
# Guess: 1.6989707946777344 50.00009099153543
# Lo: 1.6989669799804688, Hi: 1.6989707946777344
# Guess: 1.6989688873291016 49.99987139999156
# ...

# %%
num = 50
lo = 1
hi = 2
guess = (lo + hi)/2
print(f"lo: {lo}, Hi: {hi}, guess: {guess}")
for i in range(20):
    print(f" ===== {i} ======= ")
    if 10**guess < num:
        print("Too low. Going higher")
        lo = guess 
    else:
        print("Too high, going lower")
        hi = guess 
    print(f"lo: {lo}, Hi: {hi}")
    guess = (lo + hi)/2
    print(f"Guess: {guess}", 10 ** guess )
print(f"The final answer is: {guess}")
# Out:
# lo: 1, Hi: 2, guess: 1.5
#  ===== 0 =======
# Too low. Going higher
# lo: 1.5, Hi: 2
# Guess: 1.75 56.23413251903491
#  ===== 1 =======
# Too high, going lower
# lo: 1.5, Hi: 1.75
# Guess: 1.625 42.169650342858226
#  ===== 2 =======
# Too low. Going higher
# lo: 1.625, Hi: 1.75
# Guess: 1.6875 48.69675251658631
#  ===== 3 =======
# Too low. Going higher
# lo: 1.6875, Hi: 1.75
# Guess: 1.71875 52.32991146814947
#  ===== 4 =======
# Too high, going lower
# lo: 1.6875, Hi: 1.71875
# Guess: 1.703125 50.48065716667471
#  ===== 5 =======
# Too high, going lower
# lo: 1.6875, Hi: 1.703125
# Guess: 1.6953125 49.58068241684656
#  ===== 6 =======
# Too low. Going higher
# lo: 1.6953125, Hi: 1.703125
# Guess: 1.69921875 50.02864610575233
#  ===== 7 =======
# Too high, going lower
# lo: 1.6953125, Hi: 1.69921875
# Guess: 1.697265625 49.80416061248411
#  ===== 8 =======
# Too low. Going higher
# lo: 1.697265625, Hi: 1.69921875
# Guess: 1.6982421875 49.916277163626866
#  ===== 9 =======
# ...

# %%
def my_log(num, lo, hi, loop_count):
    guess = (lo + hi)/2
    # print(f"lo: {lo}, Hi: {hi}, guess: {guess}")
    for i in range(20):
        # print(f" ===== {i} ======= ")
        if 10**guess < num:
            # print("Too low. Going higher")
            lo = guess 
        else:
            # print("Too high, going lower")
            hi = guess 
        # print(f"lo: {lo}, Hi: {hi}")
        guess = (lo + hi)/2
    #     print(f"Guess: {guess}", 10 ** guess )
    # print(f"The final answer is: {guess}")
    return guess

# %%
result = my_log(50, 1, 3, 50)
print(result)
# Out:
# 1.698969841003418

# %%
my_log(5000, 1, 5, 50)
# Out:
# 3.6989688873291016

# %%
10 ** 3.6989688873291016
# Out:
# 4999.987139999156

# %%
Can you use this method for:
1. Square root 
2. Cube RootImpl
3. nth root
